# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dataset link: https://drive.google.com/file/d/1bnHCKZgWF1X7ldKonX36CG-V8nSsH7mS/view?usp=sharing

df = pd.read_csv('/content/drive/MyDrive/Deep Learning Class/Datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
pd.to_numeric(df.TotalCharges, errors='coerce')
# wherever there are spaces it will ignore or put NA
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]

# Here Total Charges is Blank
# 11 rows are there
# we can drop this
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df1 = df[df.TotalCharges != ' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
tenure_churn_no = df1[df1.Churn == 'No'].tenure
tenure_churn_yes = df1[df1.Churn == 'Yes'].tenure

plt.hist([tenure_churn_yes, tenure_churn_no], color=["grey","blue"], label=["Churn=Yes","Churn=No"])
plt.legend()

plt.xlabel("Tenure")
plt.ylabel("Number of Customers")
plt.title("Customer Churn Prediction Visualization")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
mc_churn_no = df1[df1.Churn == 'No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn == 'Yes'].MonthlyCharges

plt.hist([mc_churn_yes, mc_churn_no], color=["grey","blue"], label=["Churn=Yes","Churn=No"])
plt.legend()

plt.xlabel("Monthly Charges")
plt.ylabel("Number of Customers")
plt.title("Customer Churn Prediction Visualization")
plt.show()

# %%
def print_unique_col_values(df1):
  for column in df1:
    if df1[column].dtypes == 'object':
      print(f'{column}:{df1[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No phone service' 'No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes' 'No internet service']
# OnlineBackup:['Yes' 'No' 'No internet service']
# DeviceProtection:['No' 'Yes' 'No internet service']
# TechSupport:['No' 'Yes' 'No internet service']
# StreamingTV:['No' 'Yes' 'No internet service']
# StreamingMovies:['No' 'Yes' 'No internet service']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
df1.replace('No internet service', 'No', inplace=True)
df1.replace('No phone service', 'No', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
print_unique_col_values(df1)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes']
# OnlineBackup:['Yes' 'No']
# DeviceProtection:['No' 'Yes']
# TechSupport:['No' 'Yes']
# StreamingTV:['No' 'Yes']
# StreamingMovies:['No' 'Yes']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity',
                  'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

for col in yes_no_columns:
  df1[col].replace({'Yes': 1, 'No': 0}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df1['gender'].replace({'Male': 1, 'Female': 0}, inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# InternetService:['DSL' 'Fiber optic' 'No']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 347        0              0        1           0      70             1
# 6150       1              0        0           0      32             1
# 6791       1              0        0           0      19             0
# 1727       1              0        0           0      31             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 347               0               0             0                 0  ...
# 6150              0               0             0                 0  ...
# 6791              0               0             0                 1  ...
# 1727              1               0             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 347                     0                            0                   1
# 6150                    0                            1                   0
# 6791                    1                            0                   0
# 1727                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 347                         0                  0                  1
# 6150                        1                  0                  0
# 6791                        1                  0                  0
# 1727                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 347                                         1
# 6150                                        0
# 6791                                        0
# 1727                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 347                                       0                               0
# 6150                                      0                               1
# 6791                                      0                               1
# 1727                                      0                               1
#
#       PaymentMethod_Mailed check
# 347                            0
# 6150                           0
# 6791                           0
# 1727                           0
#
# [4 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4658       0              0        0           0  0.098592             1
# 3032       1              0        0           0  0.225352             1
# 6226       1              0        0           0  0.901408             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4658              0               0             0                 0  ...
# 3032              0               0             0                 0  ...
# 6226              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4658                    1                            0                   0
# 3032                    0                            0                   1
# 6226                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4658                        1                  0                  0
# 3032                        0                  0                  1
# 6226                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4658                                        0
# 3032                                        0
# 6226                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4658                                      0                               0
# 3032                                      1                               0
# 6226                                      0                               0
#
#       PaymentMethod_Mailed check
# 4658                           1
# 3032                           0
# 6226                           1
#
# [3 rows x 27 columns]

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.l
    ayers.Dense(1, activation='sigmoid'),
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5224 - accuracy: 0.7312
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.7934
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4212 - accuracy: 0.8005
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8009
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8052
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4138 - accuracy: 0.8059
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8032
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8064
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8071
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8092
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8055
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8114
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8110
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.8098
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8078
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8124
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8123
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4042 - accuracy: 0.8105
# Epoch 19/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4027 - accuracy: 0.8133
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8116
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8124
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8135
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8165
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8162
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8153
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8153
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8146
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8155
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8162
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8165
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8148
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8142
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8165
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8160
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8156
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8165
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8185
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8192
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8174
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8183
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8203
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8171
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8174
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8174
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8181
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8185
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8180
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8197
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8176
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8219
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8178
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8196
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8185
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8187
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.8194
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8212
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3899 - accuracy: 0.8181
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8224
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8188
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8206
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8199
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8199
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8188
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8204
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8199
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3881 - accuracy: 0.8224
# Epoch 67/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3881 - accuracy: 0.8201
# Epoch 68/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3879 - accuracy: 0.8219
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8219
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8199
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8220
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8203
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8210
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8210
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8220
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8187
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8201
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8199
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8194
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8231
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8212
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8226
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8222
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8206
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8244
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8217
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.8242
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8212
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8217
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8219
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.8219
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8224
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8206
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8238
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8228
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8222
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8201
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8204
# Epoch 99/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3840 - accuracy: 0.8226
# Epoch 100/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.8228

# %%
model.evaluate(X_test,y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.7768
# [0.4516161382198334, 0.7768301367759705]

# %%
yp = model.predict(X_test)
yp[:10]
# Out:
# array([[0.27497506],
#        [0.5825581 ],
#        [0.02306443],
#        ...,
#        [0.74747735],
#        [0.6600373 ],
#        [0.4897397 ]], dtype=float32)

# %%
y_pred = []

for element in yp:
  if element > 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85       999
#            1       0.64      0.54      0.58       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.71      0.72      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
import seaborn as sns

cm = tf.math.confusion_matrix(labels=y_test, predictions=y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
